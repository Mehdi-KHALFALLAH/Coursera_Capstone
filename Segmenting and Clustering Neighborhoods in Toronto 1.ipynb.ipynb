# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from BeautifulSoup4) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from wikipedia) (2.25.1)
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from wikipedia) (4.9.3)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (4.0.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from beautifulsoup4->wikipedia) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Start by creating a new Notebook for this assignment.
# setup import
import pandas as pd 
import wikipedia as wp
from bs4 import BeautifulSoup 
import requests

# Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe
# enter the h1 element in wp.page(h1)
html = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")

# determine the index of your table
df = pd.read_html(html, header = 0)[0]

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(url).text
Canada_data = BeautifulSoup(source, 'lxml')

# %%
# creat a new Dataframe
column_names = ['Postalcode','Borough','Neighborhood']
toronto = pd.DataFrame(columns = column_names)

# %%
content = Canada_data.find('div', class_='mw-parser-output')
table = content.table.tbody
postcode = 0
borough = 0
neighborhood = 0

for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
    toronto = toronto.append({'Postalcode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# clean dataframe 
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1
                                 
df = toronto.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head()
# Out:
#                                           Postalcode                Borough  \
# 0                              \nM1ANot assigned\n\n  \nM2ANot assigned\n\n
# 1              \nM1BScarborough(Malvern / Rouge)\n\n  \nM2BNot assigned\n\n
# 2  \nM1CScarborough(Rouge Hill / Port Union / Hig...  \nM2CNot assigned\n\n
# 3  \nM1EScarborough(Guildwood / Morningside / Wes...  \nM2ENot assigned\n\n
# 4                       \nM1GScarborough(Woburn)\n\n  \nM2GNot assigned\n\n
#
#                                         Neighborhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
df.head()
# Out:
#                                      M1ANot assigned  \
# 0                    M1BScarborough(Malvern / Rouge)
# 1  M1CScarborough(Rouge Hill / Port Union / Highl...
# 2  M1EScarborough(Guildwood / Morningside / West ...
# 3                             M1GScarborough(Woburn)
# 4                          M1HScarborough(Cedarbrae)
#
#                     M2ANot assigned  \
# 0                   M2BNot assigned
# 1                   M2CNot assigned
# 2                   M2ENot assigned
# 3                   M2GNot assigned
# 4  M2HNorth York(Hillcrest Village)
#
#                             M3ANorth York(Parkwoods)  \
# 0                      M3BNorth York(Don Mills)North
# 1     M3CNorth York(Don Mills)South(Flemingdon Park)
# 2                                    M3ENot assigned
# 3                                    M3GNot assigned
# 4  M3HNorth York(Bathurst Manor / Wilson Heights ...
#
#                   M4ANorth York(Victoria Village)  \
# 0  M4BEast York(Parkview Hill / Woodbine Gardens)
# 1                  M4CEast York(Woodbine Heights)
# 2                    M4EEast Toronto(The Beaches)
# 3                           M4GEast York(Leaside)
# 4                  M4HEast York(Thorncliffe Park)
#
#    M5ADowntown Toronto(Regent Park / Harbourfront)  \
# 0    M5BDowntown Toronto(Garden District, Ryerson)
# 1              M5CDowntown Toronto(St. James Town)
# 2                 M5EDowntown Toronto(Berczy Park)
# 3          M5GDowntown Toronto(Central Bay Street)
# 4  M5HDowntown Toronto(Richmond / Adelaide / King)
#
#   M6ANorth York(Lawrence Manor / Lawrence Heights)  \
# 0                         M6BNorth York(Glencairn)
# 1                      M6CYork(Humewood-Cedarvale)
# 2                     M6EYork(Caledonia-Fairbanks)
# 3                    M6GDowntown Toronto(Christie)
# 4   M6HWest Toronto(Dufferin / Dovercourt Village)
#
#   M7AQueen's Park(Ontario Provincial Government)  M8ANot assigned  \
# 0                                M7BNot assigned  M8BNot assigned
# 1                                M7CNot assigned  M8CNot assigned
# 2                                M7ENot assigned  M8ENot assigned
# 3                                M7GNot assigned  M8GNot assigned
# 4                                M7HNot assigned  M8HNot assigned
#
#                       M9AEtobicoke(Islington Avenue)
# 0  M9BEtobicoke(West Deane Park / Princess Garden...
# 1  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 2                                    M9ENot assigned
# 3                                    M9GNot assigned
# 4                                    M9HNot assigned

# %%
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-29e15646f158> in <module>
#       2     return ', '.join(sorted(grouped['Neighborhood'].tolist()))
#       3
# ----> 4 grp = df.groupby(['Postalcode', 'Borough'])
#       5 df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     784                 in_axis, name, level, gpr = False, None, gpr, None
#     785             else:
# --> 786                 raise KeyError(gpr)
#     787         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     788             # Add key to exclusions
#
# KeyError: 'Postalcode'

# %%
df.columns=["Postalcode","Borough","Neighbourhood"]

# %%
df = df[df.Borough != 'Not assigned']

# %%
df
# Out:
#                                            Postalcode  \
# 0                               \nM1ANot assigned\n\n
# 1               \nM1BScarborough(Malvern / Rouge)\n\n
# 2   \nM1CScarborough(Rouge Hill / Port Union / Hig...
# 3   \nM1EScarborough(Guildwood / Morningside / Wes...
# 4                        \nM1GScarborough(Woburn)\n\n
# 5                     \nM1HScarborough(Cedarbrae)\n\n
# 6           \nM1JScarborough(Scarborough Village)\n\n
# 7   \nM1KScarborough(Kennedy Park / Ionview / East...
# 8   \nM1LScarborough(Golden Mile / Clairlea / Oakr...
# 9   \nM1MScarborough(Cliffside / Cliffcrest / Scar...
# 10  \nM1NScarborough(Birch Cliff / Cliffside West)...
# 11  \nM1PScarborough(Dorset Park / Wexford Heights...
# 12           \nM1RScarborough(Wexford / Maryvale)\n\n
# 13                   \nM1SScarborough(Agincourt) \n\n
# 14  \nM1TScarborough(Clarks Corners / Tam O'Shante...
# 15  \nM1VScarborough(Milliken / Agincourt North / ...
# 16  \nM1WScarborough(Steeles West / L'Amoreaux Wes...
# 17                  \nM1XScarborough(Upper Rouge)\n\n
# 18                              \nM1YNot assigned\n\n
# 19                              \nM1ZNot assigned\n\n
#
#                                               Borough  \
# 0                               \nM2ANot assigned\n\n
# 1                               \nM2BNot assigned\n\n
# 2                               \nM2CNot assigned\n\n
# 3                               \nM2ENot assigned\n\n
# 4                               \nM2GNot assigned\n\n
# 5              \nM2HNorth York(Hillcrest Village)\n\n
# 6   \nM2JNorth York(Fairview / Henry Farm / Oriole...
# 7                \nM2KNorth York(Bayview Village)\n\n
# 8      \nM2LNorth York(York Mills / Silver Hills)\n\n
# 9       \nM2MNorth York(Willowdale / Newtonbrook)\n\n
# 10               \nM2NNorth York(Willowdale)South\n\n
# 11               \nM2PNorth York(York Mills West)\n\n
# 12                \nM2RNorth York(Willowdale)West\n\n
# 13                              \nM2SNot assigned\n\n
# 14                              \nM2TNot assigned\n\n
# 15                              \nM2VNot assigned\n\n
# 16                              \nM2WNot assigned\n\n
# 17                              \nM2XNot assigned\n\n
# 18                              \nM2YNot assigned\n\n
# 19                              \nM2ZNot assigned\n\n
#
#                                         Neighbourhood
# 0                      M9AEtobicoke(Islington Avenue)
# 1   M9BEtobicoke(West Deane Park / Princess Garden...
# 2   M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                     M9ENot assigned
# 4                                     M9GNot assigned
# 5                                     M9HNot assigned
# 6                                     M9JNot assigned
# 7                                     M9KNot assigned
# 8                        M9LNorth York(Humber Summit)
# 9                    M9MNorth York(Humberlea / Emery)
# 10                                    M9NYork(Weston)
# 11                            M9PEtobicoke(Westmount)
# 12  M9REtobicoke(Kingsview Village / St. Phillips ...
# 13                                    M9SNot assigned
# 14                                    M9TNot assigned
# 15  M9VEtobicoke(South Steeles / Silverstone / Hum...
# 16  M9WEtobicokeNorthwest(Clairville / Humberwood ...
# 17                                    M9XNot assigned
# 18                                    M9YNot assigned
# 19                                    M9ZNot assigned

# %%
result = df.groupby(['Postalcode','Borough'], sort=False).agg( ', '.join)

# %%
df = df[df.Borough != 'Not assigned']

# %%
df.loc[df['Neighbourhood'] =='Not assigned' , 'Neighbourhood'] = df['Borough']
df.head(10)
# Out:
#                                           Postalcode  \
# 0                              \nM1ANot assigned\n\n
# 1              \nM1BScarborough(Malvern / Rouge)\n\n
# 2  \nM1CScarborough(Rouge Hill / Port Union / Hig...
# 3  \nM1EScarborough(Guildwood / Morningside / Wes...
# 4                       \nM1GScarborough(Woburn)\n\n
# 5                    \nM1HScarborough(Cedarbrae)\n\n
# 6          \nM1JScarborough(Scarborough Village)\n\n
# 7  \nM1KScarborough(Kennedy Park / Ionview / East...
# 8  \nM1LScarborough(Golden Mile / Clairlea / Oakr...
# 9  \nM1MScarborough(Cliffside / Cliffcrest / Scar...
#
#                                              Borough  \
# 0                              \nM2ANot assigned\n\n
# 1                              \nM2BNot assigned\n\n
# 2                              \nM2CNot assigned\n\n
# 3                              \nM2ENot assigned\n\n
# 4                              \nM2GNot assigned\n\n
# 5             \nM2HNorth York(Hillcrest Village)\n\n
# 6  \nM2JNorth York(Fairview / Henry Farm / Oriole...
# 7               \nM2KNorth York(Bayview Village)\n\n
# 8     \nM2LNorth York(York Mills / Silver Hills)\n\n
# 9      \nM2MNorth York(Willowdale / Newtonbrook)\n\n
#
#                                        Neighbourhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned
# 5                                    M9HNot assigned
# 6                                    M9JNot assigned
# 7                                    M9KNot assigned
# 8                       M9LNorth York(Humber Summit)
# 9                   M9MNorth York(Humberlea / Emery)

# %%
df.shape
# Out:
# (20, 3)
